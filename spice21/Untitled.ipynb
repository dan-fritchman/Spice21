# %%
import json
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %%
data = json.load(open("data.ac.json", "r"))
data
# Out:
# [[1.0,
#   0.0,
#   0.0,
#   -0.7963538407310079,
#   0.00036680674841518563,
#   1.0,
#   0.0,
#   -7.96353840731008e-06,
#   3.6680674841518566e-09,
#   -1.9153844813604197e-19,
#   -1.371040939249651e-15],
#  [1.035142166679344,
#   0.0,
#   0.0,
#   -0.7963538407310079,
#   0.00036680674841518563,
#   1.0,
#   0.0,
#   -7.96353840731008e-06,
#   3.6680674841518566e-09,
#   -1.9153844813604197e-19,
#   -1.371040939249651e-15],
#  [1.0715193052376066,
#   0.0,
#   0.0,
#   -0.7963538407310079,
#   0.00036680674841518563,
#   1.0,
#   0.0,
#   -7.96353840731008e-06,
#   3.6680674841518566e-09,
#   -1.9153844813604197e-19,
#   -1.371040939249651e-15],
#  [1.1091748152624015,
#   0.0,
#   0.0,
#   -0.7963538407310079,
#   0.00036680674841518563,
#   1.0,
#   0.0,
#   -7.96353840731008e-06,
#   3.6680674841518566e-09,
#   -1.9153844813604197e-19,
#   -1.371040939249651e-15],
#  [1.1481536214968833,
#   0.0,
#   0.0,
#   -0.7963538407310079,
#   0.00036680674841518563,
#   1.0,
# ...

# %%
f = [x[0] for x in data]
vdd = [(x[1],x[2]) for x in data]
d = [(x[3],x[4]) for x in data]

# %%
db = [20 * np.log10(np.sqrt(v[0]**2 + v[1]**2)) for v in d]

# %%
plt.plot(f, db)
plt.xscale('log')
plt.grid()
